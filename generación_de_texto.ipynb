# %% [markdown]
# # Ejercicio Generación de texto:
#
#   * Carlos López Muñoz
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Máster de FP en Inteligencia Artifical y Big Data
# Generador de historia en Python con la API
# de Generation Text WebUI .

# %% [markdown]
# Para este proyecto he utilizado la interfaz de [oobabooga](https://github.com/oobabooga). Su [repositorio](https://github.com/oobabooga/text-generation-webui).

# %% [markdown]
# El objetivo es instalar un modelo de generación de texto y que con un ejecutable de python me recoga una serie de datos y que me cree una historia.
#
# Para ello instale multiples modelos :
#
# * AIDC-AI_Marco-o1
# * EleutherAI_gpt-neo-1.3B
# * EleutherAI_gpt-neo-2.7B
# * HuggingFaceTB_SmolLM2-1.7B-Instruct
# * nvidia_Hymba-1.5B-Instruct
# * Qwen_Qwen2.5-1.5B-Instruct
#
# De los cuales solo me funcionaron
# * EleutherAI_gpt-neo-1.3B
# * EleutherAI_gpt-neo-2.7B
# * Qwen_Qwen2.5-1.5B-Instruct
# * HuggingFaceTB_SmolLM2-1.7B-Instruct
#
# Y de los que realmente me dieron una respuesta "coherente" / ( Aclarar que hay modelos que no me funcionaron y otros me daban respuesta que no tienen nada que ver o me lo dan en chino con ingles y español ).
#
# * EleutherAI_gpt-neo-2.7B
# * Qwen_Qwen2.5-1.5B-Instruct
#
# Y el que mas se acerca a lo que realmente quiero es :
#
# * Qwen_Qwen2.5-1.5B-Instruct
#
# (Se me paso sacar la captura de la respuesta, pero guarde las historias para leerlas.)
# **Que la historia que me dio fue :**
#
# Entraron un respetuoso hombre de mediana edad y una mujer joven que parecían dos extraños. El hombre de mediana edad sacó una llave dorada y abrió una pequeña caja. Dentro había varios teléfonos móviles y una cámara. Les sonrió, luego encendió una vela delante de ellos y dijo: "Este secreto será nuestro para siempre". Se fue, dejándolos atónitos y confundidos.
# Carlos y Dario afirman que no se conocían y no tenían nada que hacer en Benamocarra. Sin embargo, a pesar del misterio que rodeaba el lugar, se decidieron a seguir el hombre y la mujer que había salido. Mientras caminaban por las calles de la ciudad, descubrieron una serie de encantos y sorpresas que los atraían cada vez más.
# Carlos y Dario finalmente llegaron a una finca en un pequeño pueblo. A pesar de la distancia, se sintieron como si estuvieran en casa. El lugar era encantador y el jardín estaba lleno de flores y árboles. El hombre y la mujer, sin embargo, se mostraron incomodos y nerviosos al verles.
# "¿Por qué están aquí?", preguntó el hombre.
# "Nos gusta mucho esta ciudad", respondió Dario. "¿Podemos pasar un poco más tiempo aquí?"
# El hombre asintió y los llevó a un pequeño salón. En la pared estaba un lienzo con una pintura de un sol brillante y un cielo despejado. El hombre, Dario y Carlos se sentaron y empezaron a conversar.
# Era un amanecer tranquilo y soleado. Los tres se sentían libres y aliviados. El hombre y la mujer, sin embargo, parecían inseguros. Dario se acercó a ellos y le pidió,...
#
# Con anterioridad, Dario había provocado una serie de incidentes en la ciudad, causando estragos y desorden. Por eso, Carlos había decidido que Dario debía irse de la ciudad. Pero, sin embargo, Dario estaba confundido e inquieto, dudando de si debía dejar la ciudad o si debía proteger a Carlos y a su familia.
# Carlos, en su lugar de refugio, había estado pensando en la necesidad de proteger

# %% [markdown]
# El segúndo mejor fue : *** EleutherAI_gpt-neo-2.7B**
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ahora pasemos al desglose de como hice el ejcutable para que funcionara :
#
# Lo primero es indicar las librerias que son necesarias, en mi caso requests y json.
#
# `import requests`
#
# `import json`
#
# Guardamos la dirección de la api y la información que se le pasara en variables.
#
# `url = "http://127.0.0.1:5000/v1/completions": Esta es la dirección local de la API a la que se enviarán los datos.`
#
# `headers = {"Content-Type": "application/json"}: Esto le dice a la API que los datos que enviamos están en formato JSON.`
#
# Se crea una función para definir cuanta creatividad utilizara para generar el texto.
#
# ![image-2.png](attachment:image-2.png)
#
# La siguiente función es la que se encarga de recoger los datos del usuario, enviarlos a la api y que nos devuelva la historia generada.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Y bueno. Vasicamente si lo ejecutas con **python chat.py** te pide que rellenes los campos, le indiques que tan creativo tienen que ser y despues de un rato de espera te generara una "historia".
